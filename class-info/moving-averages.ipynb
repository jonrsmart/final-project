# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from config import akey
file2 = 'api-data/all_info.csv'
all_stocks = pd.read_csv(file2)

# %%
all_stocks.head()
# Out:
#          Date  Close Ticker  Year  Month              Sector  \
# 0  1999-12-31  20.00    CLB  1999     12              Energy
# 1  1999-12-31  10.38   CENT  1999     12  Consumer Defensive
# 2  1999-12-31   0.08   RDNT  1999     12          Healthcare
# 3  1999-12-31  11.63    ESE  1999     12          Technology
# 4  1999-12-31  20.75    FBP  1999     12  Financial Services
#
#                              Industry  Full Time Emp
# 0      Oil & Gas Equipment & Services         3800.0
# 1                      Packaged Foods         5600.0
# 2              Diagnostics & Research         6165.0
# 3  Scientific & Technical Instruments         2713.0
# 4                      Banks-Regional         2674.0

# %%
#take all stocks csv, filter based on list of chosen sectors and output 
sector = ['Basic Materials','Consumer Defensive','Technology']
selected = all_stocks.loc[all_stocks['Sector'].isin(sector)]
pct_chg2020 = 'api-data/yearly_summary/ticker_pct_chg_2020.csv'
changes = pd.read_csv(pct_chg2020)

# %%
selected['Date'] = pd.to_datetime(selected['Date'], format='%Y-%m-%d')
selected.drop(columns=['Year', 'Month','Industry','Sector','Full Time Emp'], inplace=True)
# Out:
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\jonrs\anaconda3\envs\case_python\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#taking the top 20 individual stocks from the selected sectors and returning to new dataframe. 
#output new dataframe to a CSV. 
top20 = sel_changes.nlargest(20, columns='pct change')
top20['pct change'] = top20['pct change'].round(2)
top20.to_csv('api-data/top20bysector.csv', index=False)
top20
# Out:
#     Ticker  pct change              Sector  \
# 303   STMP       63.12          Technology
# 164   UNFI       52.35  Consumer Defensive
# 349   RYAM       52.25     Basic Materials
# 198   CENX       50.61     Basic Materials
# 537   TTEC       49.36          Technology
# 571   BRKS       49.15          Technology
# 354    CLF       48.15     Basic Materials
# 555   FIZZ       47.93  Consumer Defensive
# 144   ALRM       47.27          Technology
# 88    MSTR       46.80          Technology
# 444    UIS       46.12          Technology
# 485   VICR       45.80          Technology
# 565    BGS       44.92  Consumer Defensive
# 17    LTHM       43.75     Basic Materials
# 382   FORM       42.33          Technology
# 400   SPSC       41.75          Technology
# 403    BIG       40.68  Consumer Defensive
# 314    KRA       40.68     Basic Materials
# 55    COHU       40.22          Technology
# 524   EGHT       39.94          Technology
#
#                                 Industry  Full Time Emp  Year
# 303                 Software-Application         1313.0  2020
# 164                    Food Distribution        28300.0  2020
# 349                            Chemicals         4000.0  2020
# 198                             Aluminum         2079.0  2020
# 537      Information Technology Services        56200.0  2020
# 571  Semiconductor Equipment & Materials         3159.0  2020
# 354                                Steel         2372.0  2020
# 555              Beverages-Non-Alcoholic         1550.0  2020
# 144                 Software-Application         1361.0  2020
# 88                  Software-Application         2073.0  2020
# 444      Information Technology Services        20800.0  2020
# 485                Electronic Components          993.0  2020
# 565                       Packaged Foods         2952.0  2020
# 17                   Specialty Chemicals          800.0  2020
# 382                       Semiconductors         1836.0  2020
# 400              Software-Infrastructure         1363.0  2020
# 403                      Discount Stores        10500.0  2020
# 314                  Specialty Chemicals         1944.0  2020
# 55   Semiconductor Equipment & Materials         3200.0  2020
# 524                 Software-Application         1675.0  2020

# %%
choice = selected.pivot(index='Date',columns='Ticker', values='Close')
choice.fillna(0, inplace=True)
choice['Total'] = choice.mean(axis=1)
choice
# Out:
# Ticker       AAOI   ACLS    ADTN   AGYS   ALRM    ANDE   APEI   ASIX    AVD  \
# Date
# 1999-12-31   0.00   0.00  51.440  14.44   0.00   8.250   0.00   0.00   6.13
# 2000-01-31   0.00   0.00  64.750  13.64   0.00   7.563   0.00   0.00   6.75
# 2000-02-29   0.00   0.00  73.560  18.38   0.00   7.625   0.00   0.00   7.25
# 2000-03-31   0.00   0.00  59.440  15.75   0.00   7.000   0.00   0.00   7.88
# 2000-04-28   0.00   0.00  67.560  15.31   0.00   7.469   0.00   0.00   8.87
# ...           ...    ...     ...    ...    ...     ...    ...    ...    ...
# 2020-08-31  11.63  23.63  11.090  25.37  59.87  17.730  31.44  12.73  14.15
# 2020-09-30  11.25  22.00  10.255  24.16  55.25  19.170  28.19  12.88  13.14
# 2020-10-30   8.78  22.07  10.690  27.08  58.33  21.690  28.27  15.22  12.92
# 2020-11-30   8.31  26.98  12.635  37.36  75.91  22.730  31.04  17.77  15.16
# 2020-12-15   8.41  28.81  14.650  39.22  83.31  24.510  32.13  20.19  16.19
#
# Ticker        BCC  ...    UVV   VECO    VGR    VIAV   VICR   VRTU    WDFC  \
# Date               ...
# 1999-12-31   0.00  ...  22.81  46.81  14.94   0.000  40.50   0.00   22.13
# 2000-01-31   0.00  ...  20.44  54.88  16.19   0.000  40.75   0.00   18.75
# 2000-02-29   0.00  ...  16.38  82.13  13.25   0.000  22.75   0.00   18.50
# 2000-03-31   0.00  ...  15.06  74.00  12.19   0.000  18.00   0.00   21.00
# 2000-04-28   0.00  ...  18.88  62.13  13.88   0.000  26.00   0.00   19.94
# ...           ...  ...    ...    ...    ...     ...    ...    ...     ...
# 2020-08-31  45.80  ...  43.41  11.89  10.07  13.335  87.03  39.54  204.38
# 2020-09-30  39.92  ...  41.88  11.67   9.69  11.730  77.73  49.16  189.31
# 2020-10-30  38.38  ...  39.85  12.73   9.19  12.350  78.00  50.30  243.38
# 2020-11-30  43.25  ...  45.51  16.62  11.24  13.545  81.96  50.08  254.31
# 2020-12-15  47.68  ...  51.04  18.23  12.81  13.900  92.35  50.25  264.00
#
# Ticker       XPER   ZEUS      Total
# Date
# 1999-12-31   0.00   4.75  19.253066
# 2000-01-31   0.00   4.50  18.696493
# 2000-02-29   0.00   4.50  22.670404
# 2000-03-31   0.00   4.00  20.079390
# 2000-04-28   0.00   4.75  18.744044
# ...           ...    ...        ...
# 2020-08-31  12.53  11.00  43.517610
# 2020-09-30  11.49  11.36  41.392243
# 2020-10-30  12.40  11.41  42.961838
# 2020-11-30  19.08  14.84  49.923493
# 2020-12-15  19.82  15.95  52.151949
#
# [253 rows x 137 columns]

# %%
#plot all stocks in our chosen sectors with a moving average and overall portfolio average. 
#moving average .ewm function learned from https://www.learndatasci.com/tutorials/python-finance-part-3-moving-average-trading-strategy/
#looping through the ticker list and outputting to PNG with stock ticker in filename

start_date = '1999-12-31'
end_date = '2020-12-15'
tickers = top20['Ticker'].to_list()
for ticker in tickers:
    
    fig, ax = plt.subplots(figsize=(9,6))
    my_year_month_fmt = dates.DateFormatter('%m/%Y')
    choice_ema = choice.ewm(span=6, adjust=False).mean()
    ax.plot(choice.loc[start_date:end_date, :].index, choice.loc[start_date:end_date, ticker], label=f'{ticker} Price')
    ax.plot(choice_ema.loc[start_date:end_date, :].index, choice_ema.loc[start_date:end_date, ticker], label = f'{ticker} 6-Months Moving Average')
    ax.plot(choice.loc[start_date:end_date, :].index, choice.loc[start_date:end_date, 'Total'], label='Average of All Stocks')
    ax.legend(fontsize=12,loc='best')
    ax.set_ylabel('Price in $', fontsize=14)
    ax.xaxis_date()
    ax.xaxis.set_major_formatter(my_year_month_fmt)
    plt.grid(which='major', axis='y')
    ax.set_title(f'Monthly Prices for {ticker} from 1999 to 2020 with Moving Averages', fontsize=14, fontweight='bold')
    fig.savefig(f'images/{ticker}_avg.png')

# %%
#same as above except limiting date ranges to just 2019 and 2020. 
start_date = '2019-01-31'
end_date = '2020-12-15'
tickers = top20['Ticker'].to_list()
for ticker in tickers:
    
    fig, ax1 = plt.subplots(figsize=(9,6))
    my_year_month_fmt = dates.DateFormatter('%m/%Y')
    choice_ema = choice.ewm(span=6, adjust=False).mean()
    ax1.plot(choice.loc[start_date:end_date, :].index, choice.loc[start_date:end_date, ticker], label=f'{ticker} Price')
    ax1.plot(choice_ema.loc[start_date:end_date, :].index, choice_ema.loc[start_date:end_date, ticker], label = f'{ticker} 6-Months Moving Average')
    ax2=ax1.twinx()
    ax2.plot(choice.loc[start_date:end_date, :].index, choice.loc[start_date:end_date, 'Total'],color='green',label='Average of All Stocks')
    ax1.legend(loc='lower right', fontsize=12)
    ax2.legend(loc='best', fontsize=12)
    ax.set_ylabel('Price in $', fontsize=14)
    ax2.set_ylabel('All Stocks Avg Price in $', fontsize=14)
    ax1.xaxis_date()
    ax1.xaxis.set_major_formatter(my_year_month_fmt)
    ax1.set_title(f'Monthly Prices for {ticker} from 2019 to 2020 with Moving Averages', fontsize=14, fontweight='bold')
    fig.savefig(f'images/{ticker}_avg_2019-2020.png')
